# %% [markdown]
# # Workshop #1: Runtime Analysis
# ## Tristan De Alwis; Marina Kupina
#
# ### Git-hub accounts https://github.com/maritum

# %%
import time
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question #1

# %% [markdown]
# ### <font color=green>Solution explanation</font>
#
# __1.__ Implemented algorithm, which compares the performance of the `list[index]` operator on lists
#
# __2.__ During the experiment it was generated lists different lengths in loop, then was chosen random index, which should be deleted. For time measurements was used module `timeit`, which was described in the book Problem Solving with Algorithms and Data Structures Using Python
#
# __3.__ It was confirmed that the `list[index]` operator for lists is $O(1)$
#
# __<font color=green>4*.</font>__ Created plot, which demonstrare results (using `matplotlib`)

# %%
import matplotlib
import timeit 
import random
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import set_matplotlib_formats

# %%
'Function list_processing return element of the list'
def list_processing(arr,index):
    return arr[index]

# %% [markdown]
# ### Printed results

# %%
'Creation for-loop in order to measure time, increasing size of list'
for i in range(10_000, 5_000_001, 250_000):
    
    'Creation a list, using the most time-efficient methods' 
    'according to Chapter 2.6 of the book Problem Solving with Algorithms and Data Structures Using Python'
    array = list(range(i)) 
    
    'Choose random index for further selection'
    index = random.randint(0,i-1)
    
    'Using a Timer object, timing measurements by running functions list_processing'
    time_list = timeit.Timer("list_processing(array,index)", "from __main__ import list_processing, array, index")
     
        

    'Print results, depending on list size'
    print('Selection of an element out of {} is required {:.6f} for list'
          .format(i, time_list.timeit(number=1)))
# Out:
# Selection of an element out of 10000 is required 0.000002 for list
# Selection of an element out of 260000 is required 0.000001 for list
# Selection of an element out of 510000 is required 0.000002 for list
# Selection of an element out of 760000 is required 0.000002 for list
# Selection of an element out of 1010000 is required 0.000002 for list
# Selection of an element out of 1260000 is required 0.000001 for list
# Selection of an element out of 1510000 is required 0.000001 for list
# Selection of an element out of 1760000 is required 0.000001 for list
# Selection of an element out of 2010000 is required 0.000001 for list
# Selection of an element out of 2260000 is required 0.000001 for list
# Selection of an element out of 2510000 is required 0.000001 for list
# Selection of an element out of 2760000 is required 0.000002 for list
# Selection of an element out of 3010000 is required 0.000002 for list
# Selection of an element out of 3260000 is required 0.000001 for list
# ...

# %% [markdown]
# ### Visualisation

# %%
'Initialization of y-axis'
y = []

'Index initialization as constant, in order to make the plot smoother'
index = 1

'Creation for-loop in order to measure time, increasing size of list'
for i in range(10_000, 2_000_001, 30_000):
    array = list(range(i))
    
    time_list = timeit.Timer("list_processing(array,index)", "from __main__ import list_processing, array, index")

    'Append results for further visualisation'
    y.append(time_list.timeit(number=1)*10**6)

# %%
'Initialization of x-axis'
x = np.arange(10000, 2_000_001, 30_000)

'Description of axises, sizes, labels'
fig, ax = plt.subplots()
plt.ylim(ymin=-1, ymax=100)
plt.xlim(xmin=10000, xmax=2000001)
plt.ylabel("Running Time (microsecond)")
plt.xlabel("Size of input (number of elements)")
plt.xticks(np.arange(0,2000001, 500000))

'Using markers for better visualisation, without lines'
ax.plot(x, y, label='Time complicity for operator $list[index]$',  marker = '^', linestyle='', color='g')


legend = plt.legend(loc='upper center', fontsize='medium')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Question #2

# %% [markdown]
# ### <font color=green>Solution explanation</font>
#
# __1.__ Implemented algorithm, which compares the performance of the `.get()` method on dictionaries
#
# __2.__ During the experiment we generated dictionaries different of different lengths using a while loop for sizes of 10 through 500. We stored the time results in an array to plot. For time measurements was used module `time`.
#
# __3.__ It was confirmed that the `.get()` method for lists is $O(1)$
#
# __<font color=green>4*.</font>__ We created a plot, which visualizes the results (using `matplotlib`)

# %%
def rntm(dict):
    start = time.time()
    
    k1 = dict.get(arry1[6])

    end = time.time()
    
    TotalTime = end-start

    return (k1, TotalTime)

# %%
x = []
y = []

n = 10
while n < 500:
    arry1 = [random.randint(0, 1000) for i in range(n)]
    arry2 = [random.randint(0, 1000) for i in range(n)]
    d1 = dict(zip(arry1,arry2))
    u,TotalTime = rntm(d1)
    x.append(n)
    y.append(TotalTime)
    n += 1
    
    
fig, ax = plt.subplots()
plt.ylim(ymin=0, ymax=.000005)
plt.xlim(xmin=0, xmax=10)
plt.ylabel("Running Time (s)")
plt.xlabel("Input Size (List Size)")
plt.xticks(np.arange(min(x), max(x)+1, 100.0))
plt.title("Complexity of '.sort()' on a List")

ax.plot(x, y, marker='^', linestyle='', color='g', label='O(1)')


legend = plt.legend(loc='upper center')

plt.show();
# Out:
# <img src="data:image/png;base64,..." width="640">
